# %%
# Imports

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import cv2
import os

import tensorflow as tf

from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

from keras.models import Sequential,load_model,Model
from keras.layers import Conv2D,MaxPooling2D,AvgPool2D,GlobalAveragePooling2D,Dense,Dropout,BatchNormalization,Flatten,Input
from sklearn.model_selection import train_test_split


from tensorflow.keras.layers import Input,Activation,Add
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
path = "/content/drive/MyDrive/UTKFace"
pixels = []
age = []
gender = []

i=0
for img in os.listdir(path):
  i=i+1
  genders = img.split("_")[1]
  img = cv2.imread(str(path)+"/"+str(img))
  img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
  img=cv2.resize(img,(100,100))
  pixels.append(np.array(img))
  gender.append(np.array(genders))

pixels = np.array(pixels)
gender = np.array(gender,np.uint64)

# %%
len(pixels)
# Out:
# 23758

# %%
len(gender)
# Out:
# 23758

# %%
x_train,x_test,y_train,y_test = train_test_split(pixels,gender,random_state=100)

# %%
len(x_train)
# Out:
# 17818

# %%
len(x_test)
# Out:
# 5940

# %%
input = Input(shape = (100,100,1))

conv1 = Conv2D(32,(3, 3), padding = 'same', strides=(1, 1), kernel_regularizer=l2(0.001))(input)
conv1 = Dropout(0.1)(conv1)
conv1 = Activation('relu')(conv1)
pool1 = MaxPooling2D(pool_size = (2,2)) (conv1)

conv2 = Conv2D(64,(3, 3), padding = 'same', strides=(1, 1), kernel_regularizer=l2(0.001))(pool1)
conv2 = Dropout(0.1)(conv2)
conv2 = Activation('relu')(conv2)
pool2 = MaxPooling2D(pool_size = (2,2)) (conv2)

conv3 = Conv2D(128,(3, 3), padding = 'same', strides=(1, 1), kernel_regularizer=l2(0.001))(pool2)
conv3 = Dropout(0.1)(conv3)
conv3 = Activation('relu')(conv3)
pool3 = MaxPooling2D(pool_size = (2,2)) (conv3)

conv4 = Conv2D(256,(3, 3), padding = 'same', strides=(1, 1), kernel_regularizer=l2(0.001))(pool3)
conv4 = Dropout(0.1)(conv4)
conv4 = Activation('relu')(conv4)
pool4 = MaxPooling2D(pool_size = (2,2)) (conv4)

flatten = Flatten()(pool4)

dense_1 = Dense(128,activation='relu')(flatten)

drop_1 = Dropout(0.2)(dense_1)

output = Dense(2,activation="sigmoid")(drop_1)

# %%
model = Model(inputs=input,outputs=output)
model.compile(optimizer="adam",loss=["sparse_categorical_crossentropy"],metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100, 100, 1)]     0
#
#  conv2d (Conv2D)             (None, 100, 100, 32)      320
#
#  dropout (Dropout)           (None, 100, 100, 32)      0
#
#  activation (Activation)     (None, 100, 100, 32)      0
#
#  max_pooling2d (MaxPooling2  (None, 50, 50, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 50, 50, 64)        18496
#
#  dropout_1 (Dropout)         (None, 50, 50, 64)        0
#
#  activation_1 (Activation)   (None, 50, 50, 64)        0
#
#  max_pooling2d_1 (MaxPoolin  (None, 25, 25, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 25, 25, 128)       73856
#
#  dropout_2 (Dropout)         (None, 25, 25, 128)       0
#
#  activation_2 (Activation)   (None, 25, 25, 128)       0
#
#  max_pooling2d_2 (MaxPoolin  (None, 12, 12, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 256)       295168
#
#  dropout_3 (Dropout)         (None, 12, 12, 256)       0
#
#  activation_3 (Activation)   (None, 12, 12, 256)       0
#
#  max_pooling2d_3 (MaxPoolin  (None, 6, 6, 256)         0
#  g2D)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 128)               1179776
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 1567874 (5.98 MB)
# Trainable params: 1567874 (5.98 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model_path='./output/allgender_model.h5'
checkpointer = ModelCheckpoint(model_path, monitor='loss',verbose=1,save_best_only=True,
                               save_weights_only=False, mode='auto',save_freq='epoch')
callback_list=[checkpointer]

# %%
save = model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=30,callbacks=[callback_list])
# Out:
# Epoch 1/30
# 557/557 [==============================] - ETA: 0s - loss: 1.1270 - accuracy: 0.7499
# Epoch 1: loss improved from inf to 1.12700, saving model to ./output/allgender_model.h5
# 557/557 [==============================] - 24s 28ms/step - loss: 1.1270 - accuracy: 0.7499 - val_loss: 0.5370 - val_accuracy: 0.8505
# Epoch 2/30
#   4/557 [..............................] - ETA: 12s - loss: 0.4394 - accuracy: 0.8750
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 557/557 [==============================] - ETA: 0s - loss: 0.5188 - accuracy: 0.8400
# Epoch 2: loss improved from 1.12700 to 0.51882, saving model to ./output/allgender_model.h5
# 557/557 [==============================] - 13s 24ms/step - loss: 0.5188 - accuracy: 0.8400 - val_loss: 0.4687 - val_accuracy: 0.8665
# Epoch 3/30
# 557/557 [==============================] - ETA: 0s - loss: 0.4592 - accuracy: 0.8595
# Epoch 3: loss improved from 0.51882 to 0.45917, saving model to ./output/allgender_model.h5
# 557/557 [==============================] - 13s 23ms/step - loss: 0.4592 - accuracy: 0.8595 - val_loss: 0.4461 - val_accuracy: 0.8668
# Epoch 4/30
# 556/557 [============================>.] - ETA: 0s - loss: 0.4171 - accuracy: 0.8708
# Epoch 4: loss improved from 0.45917 to 0.41723, saving model to ./output/allgender_model.h5
# 557/557 [==============================] - 13s 23ms/step - loss: 0.4172 - accuracy: 0.8707 - val_loss: 0.4158 - val_accuracy: 0.8759
# Epoch 5/30
# 556/557 [============================>.] - ETA: 0s - loss: 0.3886 - accuracy: 0.8763
# Epoch 5: loss improved from 0.41723 to 0.38862, saving model to ./output/allgender_model.h5
# 557/557 [==============================] - 14s 25ms/step - loss: 0.3886 - accuracy: 0.8764 - val_loss: 0.4064 - val_accuracy: 0.8724
# Epoch 6/30
# 556/557 [============================>.] - ETA: 0s - loss: 0.3661 - accuracy: 0.8838
# Epoch 6: loss improved from 0.38862 to 0.36596, saving model to ./output/allgender_model.h5
# 557/557 [==============================] - 13s 23ms/step - loss: 0.3660 - accuracy: 0.8839 - val_loss: 0.3517 - val_accuracy: 0.8867
# Epoch 7/30
# 557/557 [==============================] - ETA: 0s - loss: 0.3456 - accuracy: 0.8854
# Epoch 7: loss improved from 0.36596 to 0.34559, saving model to ./output/allgender_model.h5
# 557/557 [==============================] - 13s 23ms/step - loss: 0.3456 - accuracy: 0.8854 - val_loss: 0.3550 - val_accuracy: 0.8796
# Epoch 8/30
# 555/557 [============================>.] - ETA: 0s - loss: 0.3246 - accuracy: 0.8921
# Epoch 8: loss improved from 0.34559 to 0.32435, saving model to ./output/allgender_model.h5
# 557/557 [==============================] - 13s 24ms/step - loss: 0.3243 - accuracy: 0.8924 - val_loss: 0.3223 - val_accuracy: 0.8926
# Epoch 9/30
# 557/557 [==============================] - ETA: 0s - loss: 0.3099 - accuracy: 0.8973
# Epoch 9: loss improved from 0.32435 to 0.30990, saving model to ./output/allgender_model.h5
# 557/557 [==============================] - 13s 24ms/step - loss: 0.3099 - accuracy: 0.8973 - val_loss: 0.3226 - val_accuracy: 0.8933
# Epoch 10/30
# 556/557 [============================>.] - ETA: 0s - loss: 0.3079 - accuracy: 0.8947
# Epoch 10: loss improved from 0.30990 to 0.30784, saving model to ./output/allgender_model.h5
# 557/557 [==============================] - 13s 23ms/step - loss: 0.3078 - accuracy: 0.8947 - val_loss: 0.3281 - val_accuracy: 0.8791
# Epoch 11/30
# 555/557 [============================>.] - ETA: 0s - loss: 0.2990 - accuracy: 0.8984
# Epoch 11: loss improved from 0.30784 to 0.29893, saving model to ./output/allgender_model.h5
# 557/557 [==============================] - 13s 23ms/step - loss: 0.2989 - accuracy: 0.8985 - val_loss: 0.3325 - val_accuracy: 0.8843
# Epoch 12/30
# 555/557 [============================>.] - ETA: 0s - loss: 0.2855 - accuracy: 0.9009
# Epoch 12: loss improved from 0.29893 to 0.28526, saving model to ./output/allgender_model.h5
# 557/557 [==============================] - 13s 23ms/step - loss: 0.2853 - accuracy: 0.9009 - val_loss: 0.3101 - val_accuracy: 0.8956
# Epoch 13/30
# 557/557 [==============================] - ETA: 0s - loss: 0.2877 - accuracy: 0.9026
# Epoch 13: loss did not improve from 0.28526
# 557/557 [==============================] - 13s 24ms/step - loss: 0.2877 - accuracy: 0.9026 - val_loss: 0.3153 - val_accuracy: 0.8864
# Epoch 14/30
# 556/557 [============================>.] - ETA: 0s - loss: 0.2748 - accuracy: 0.9032
# Epoch 14: loss improved from 0.28526 to 0.27481, saving model to ./output/allgender_model.h5
# 557/557 [==============================] - 13s 24ms/step - loss: 0.2748 - accuracy: 0.9032 - val_loss: 0.3271 - val_accuracy: 0.8909
# Epoch 15/30
# 557/557 [==============================] - ETA: 0s - loss: 0.2676 - accuracy: 0.9075
# Epoch 15: loss improved from 0.27481 to 0.26762, saving model to ./output/allgender_model.h5
# 557/557 [==============================] - 13s 24ms/step - loss: 0.2676 - accuracy: 0.9075 - val_loss: 0.3016 - val_accuracy: 0.8939
# Epoch 16/30
# 556/557 [============================>.] - ETA: 0s - loss: 0.2638 - accuracy: 0.9070
# Epoch 16: loss improved from 0.26762 to 0.26363, saving model to ./output/allgender_model.h5
# 557/557 [==============================] - 13s 24ms/step - loss: 0.2636 - accuracy: 0.9071 - val_loss: 0.2993 - val_accuracy: 0.8965
# Epoch 17/30
# 555/557 [============================>.] - ETA: 0s - loss: 0.2576 - accuracy: 0.9130
# Epoch 17: loss improved from 0.26363 to 0.25747, saving model to ./output/allgender_model.h5
# 557/557 [==============================] - 13s 23ms/step - loss: 0.2575 - accuracy: 0.9130 - val_loss: 0.3091 - val_accuracy: 0.8931
# Epoch 18/30
# 555/557 [============================>.] - ETA: 0s - loss: 0.2595 - accuracy: 0.9111
# Epoch 18: loss did not improve from 0.25747
# 557/557 [==============================] - 13s 23ms/step - loss: 0.2594 - accuracy: 0.9112 - val_loss: 0.3000 - val_accuracy: 0.8926
# Epoch 19/30
# 556/557 [============================>.] - ETA: 0s - loss: 0.2514 - accuracy: 0.9147
# Epoch 19: loss improved from 0.25747 to 0.25126, saving model to ./output/allgender_model.h5
# 557/557 [==============================] - 13s 23ms/step - loss: 0.2513 - accuracy: 0.9148 - val_loss: 0.3021 - val_accuracy: 0.8902
# Epoch 20/30
# 556/557 [============================>.] - ETA: 0s - loss: 0.2449 - accuracy: 0.9183
# Epoch 20: loss improved from 0.25126 to 0.24499, saving model to ./output/allgender_model.h5
# 557/557 [==============================] - 13s 24ms/step - loss: 0.2450 - accuracy: 0.9183 - val_loss: 0.2957 - val_accuracy: 0.8971
# Epoch 21/30
# 556/557 [============================>.] - ETA: 0s - loss: 0.2472 - accuracy: 0.9183
# Epoch 21: loss did not improve from 0.24499
# 557/557 [==============================] - 13s 23ms/step - loss: 0.2472 - accuracy: 0.9183 - val_loss: 0.2983 - val_accuracy: 0.8941
# Epoch 22/30
# 557/557 [==============================] - ETA: 0s - loss: 0.2350 - accuracy: 0.9191
# Epoch 22: loss improved from 0.24499 to 0.23498, saving model to ./output/allgender_model.h5
# 557/557 [==============================] - 13s 23ms/step - loss: 0.2350 - accuracy: 0.9191 - val_loss: 0.2947 - val_accuracy: 0.8975
# Epoch 23/30
# 556/557 [============================>.] - ETA: 0s - loss: 0.2360 - accuracy: 0.9211
# Epoch 23: loss did not improve from 0.23498
# 557/557 [==============================] - 13s 23ms/step - loss: 0.2360 - accuracy: 0.9211 - val_loss: 0.2964 - val_accuracy: 0.8934
# Epoch 24/30
# 556/557 [============================>.] - ETA: 0s - loss: 0.2358 - accuracy: 0.9210
# Epoch 24: loss did not improve from 0.23498
# 557/557 [==============================] - 13s 22ms/step - loss: 0.2359 - accuracy: 0.9210 - val_loss: 0.2976 - val_accuracy: 0.8975
# Epoch 25/30
# 555/557 [============================>.] - ETA: 0s - loss: 0.2299 - accuracy: 0.9244
# Epoch 25: loss improved from 0.23498 to 0.22991, saving model to ./output/allgender_model.h5
# 557/557 [==============================] - 13s 23ms/step - loss: 0.2299 - accuracy: 0.9243 - val_loss: 0.3288 - val_accuracy: 0.8882
# Epoch 26/30
# 557/557 [==============================] - ETA: 0s - loss: 0.2253 - accuracy: 0.9259
# Epoch 26: loss improved from 0.22991 to 0.22534, saving model to ./output/allgender_model.h5
# 557/557 [==============================] - 12s 22ms/step - loss: 0.2253 - accuracy: 0.9259 - val_loss: 0.3017 - val_accuracy: 0.8998
# Epoch 27/30
# 555/557 [============================>.] - ETA: 0s - loss: 0.2309 - accuracy: 0.9235
# Epoch 27: loss did not improve from 0.22534
# 557/557 [==============================] - 12s 22ms/step - loss: 0.2308 - accuracy: 0.9236 - val_loss: 0.2942 - val_accuracy: 0.8963
# Epoch 28/30
# 557/557 [==============================] - ETA: 0s - loss: 0.2255 - accuracy: 0.9255
# Epoch 28: loss did not improve from 0.22534
# 557/557 [==============================] - 12s 22ms/step - loss: 0.2255 - accuracy: 0.9255 - val_loss: 0.2999 - val_accuracy: 0.8933
# Epoch 29/30
# 555/557 [============================>.] - ETA: 0s - loss: 0.2257 - accuracy: 0.9274
# Epoch 29: loss did not improve from 0.22534
# 557/557 [==============================] - 13s 23ms/step - loss: 0.2257 - accuracy: 0.9273 - val_loss: 0.3022 - val_accuracy: 0.8980
# Epoch 30/30
# 556/557 [============================>.] - ETA: 0s - loss: 0.2142 - accuracy: 0.9328
# Epoch 30: loss improved from 0.22534 to 0.21429, saving model to ./output/allgender_model.h5
# 557/557 [==============================] - 13s 23ms/step - loss: 0.2143 - accuracy: 0.9328 - val_loss: 0.3053 - val_accuracy: 0.8981

# %%
train_loss = save.history['loss']
test_loss = save.history['val_loss']
train_accuracy = save.history['accuracy']
test_accuracy = save.history['val_accuracy']

# %%
fig, ax = plt.subplots(ncols=2, figsize=(15,7))

ax = ax.ravel()

ax[0].plot(train_loss, label='Train Loss', color='royalblue', marker='o', markersize=5)
ax[0].plot(test_loss, label='Test Loss', color = 'orangered', marker='o', markersize=5)

ax[0].set_xlabel('Epochs', fontsize=14)
ax[0].set_ylabel('Categorical Crossentropy', fontsize=14)

ax[0].legend(fontsize=14)
ax[0].tick_params(axis='both', labelsize=12)

ax[1].plot(train_accuracy, label='Train Accuracy', color='royalblue', marker='o', markersize=5)
ax[1].plot(test_accuracy, label='Test Accuracy', color='orangered', marker='o', markersize=5)

ax[1].set_xlabel('Epochs', fontsize=14)
ax[1].set_ylabel('Accuracy', fontsize=14)

ax[1].legend(fontsize=14)
ax[1].tick_params(axis='both', labelsize=12)

fig.suptitle(x=0.5, y=0.92, t="Lineplots showing loss and accuracy of CNN model by epochs", fontsize=16)
# Out:
# Text(0.5, 0.92, 'Lineplots showing loss and accuracy of CNN model by epochs')
